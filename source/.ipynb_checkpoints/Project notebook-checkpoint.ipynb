# %%
import glob
import pickle
import os
import re
import numpy as np

from sklearn import metrics
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

# %%
def load_data():
    file_paths = [f for f in glob.glob("../data/*.txt")]
    data = {}
    for path in file_paths:
        file = open(path , "rb")
        data[os.path.basename(path)] = pickle.load(file)
        file.close()
    
    file_paths = [f for f in glob.glob("../data/secret_test_set/*.txt")]
    secret_test_data = {}
    for path in file_paths:
        file = open(path , "rb")
        secret_test_data[os.path.basename(path)] = pickle.load(file)
        file.close()
    
    return data, secret_test_data


# this is terrifying code, there ought to be a better way to split these lists into 500 word segments
def segment_data(input_data_dict):
    labels, processed_data = [], []
    for file_path, tag_list in input_data_dict.items():
        label = get_label_from_file_path(file_path)
        string = ''
        for i, tag in enumerate(tag_list):
            string += tag.lemma + ' '
            if i % 500 == 0:
                labels.append(label)
                processed_data.append(string)
                string = ''
        labels.append(label)
        processed_data.append(string)
    return labels, processed_data


def get_label_from_file_path(file_path):
    label = re.search('(?<=-)(.+)(?=-)', file_path)
    if label is None:
        return file_path
    else:
        return label.group()

# %%
# Import and process data

book_data_dict, secret_test_set = load_data()
labels, processed_data = segment_data(book_data_dict)
secret_test_labels, secret_test_processed_data = segment_data(secret_test_set)

text_classifier = Pipeline([
    ('vect', CountVectorizer(ngram_range=(1, 2))),
    ('tfidf', TfidfTransformer()),
    ('clf', SGDClassifier(loss='hinge', penalty='l2')) # see https://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html
])

# %%
X_train, X_test, y_train, y_test = train_test_split(processed_data, labels, test_size=0.20)
#print(secret_test_set['1892-Zola-LE DEBACLE.txt'][0:100])
print(secret_test_processed_data)
#print(X_test)
# Out:
# ['le ', 'DEBACLE Première partie I à deux kilomètre de Mulhouse , vers le Rhin , au milieu de le plaine fertile , le camp être dresser . sous le jour finir de ce soirée de août , au ciel trouble , traverser de lourd nuage , le tentes-abris se aligner , le faisceau luire , se espacer régulièrement sur le front de bandière ; tandis que , fusil charger , le sentinelle la|le garder , immobile , le œil perdu , là-bas , dans le brume violâtre du lointain horizon , qui monter du grand fleuve . on être arriver de Belfort vers cinq heure . il en être huit , et le homme venir seulement de toucher le vivre|vivres . mais le bois devoir se être égarer , le distribution ne avoir pouvoir avoir lieu . impossible de allumer du feu et de faire le soupe . il avoir falloir se contenter de mâcher à froid le biscuit , que on arroser de grand coup de eau-de-vie , ce qui achever de casser le jambe , déjà mou de fatigue . deux soldat pourtant , en arriérer du faisceau , près de le cantine , se entêter à vouloir enflammer un tas de bois vert , de jeune tronc de arbre que il avoir couper avec leur sabres-baïonnettes , et qui refuser obstinément de brûler . un gros|grosse fumer , noir et lent , monter dans le air du soir , de un infini tristesse . il ne y avoir là que douze mille homme , tout ce que le général Félix Douay avoir avec lui du 7e corps de armée . le premier division , appeler le veille , être partie pour Frœschwiller ; le troisième se trouver encore à Lyon ; et il se être décider à quitter Belfort , à se porter ainsi en avant avec le deuxième division , le artillerie de réserve et un division de cavalerie , incomplet . du feu avoir être apercevoir à Lorrach . un dépêche du souspréfet de Schelestadt annoncer que le prussien aller passer le Rhin à Markolsheim . le général , se sentir trop isoler à le extrême droit|droite du autre corps , sans communication avec eux , venir de hâter de autant plus son mouvement vers le frontière , que , le veille , le nouveau être arriver de le surprise désastreux de Wissembourg . de un heure à le autre , se il ne avoir pas lui même le ennemi à repousser , il pouvoir craindre de être appeler , pour soutenir le 1er corps . ce jour là , ce samedi de inquiet journée de orage , le @card@ août , on devoir se être battre quelque part , du côté de Frœschwiller : cela être dans le ciel anxieux et accabler , de grand frisson passer , de brusque souffle de vent , charger de angoisse . et , depuis deux jour , le division croire marcher au combat , le soldat se attendre ', "à trouver le prussien devant eux , au bout de ce marche forcer de Belfort à Mulhouse . le jour baisser , le retraite partir de un coin éloigner du camp , un roulement du tambour , un sonnerie du clairon , faible encore , emporter par le grand air . et Jean Macquart , qui se occuper à consolider le tente , en enfoncer le piquet davantage , se lever . au premier bruit de guerre , il avoir quitter rogne , tout saignant du drame où il venir de perdre son femme Françoise et le terre que elle lui avoir apporter ; il se être réengager à trenteneuf an , retrouver son galon de caporal , tout de suite incorporer au 106e régiment de ligne , dont on compléter le cadre ; et , parfois , il se étonner encore , de se revoir avec le capote au épaule , lui qui , après Solférino , être si joyeux de quitter le service , de ne être plus un traîneur de sabre , un tueur de monde . mais quoi faire ? quand on ne avoir plus de métier , que on ne avoir plus ni femme ni bien au soleil , que le cœur vous sauter dans le gorge de tristesse et de rage ? autant vaut-il cogner sur le ennemi , se il vous embêter . et il se rappeler son cri : ah ! bon sang ! puisqu'il ne avoir plus de courage à la travailler , il la défendre , le vieux terre de France ! Jean , debout , jeter un coup de œil dans le camp , où un agitation dernier se produire , au passage de le retraite . quelque homme courir . de autre , assoupir déjà , se soulever , se étirer de un air de lassitude irrité . lui , patient , ...

# %%
X_train, X_test, y_train, y_test = train_test_split(processed_data, labels, test_size=0.20)
    
print(X_test)
    
text_classifier.fit(X_train, y_train)
    
predicted = text_classifier.predict(X_test)
np.mean(predicted == y_test)
print(metrics.classification_report(y_test, predicted))
    
secret_test_predicted = text_classifier.predict(secret_test_processed_data)
np.mean(secret_test_predicted == secret_test_labels)
print(metrics.classification_report(secret_test_labels, secret_test_predicted))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-4beafe989c3e> in <module>()
#      15     print(X_test)
#      16
# ---> 17     text_classifier.fit(X_train, y_train)
#      18
#      19     predicted = text_classifier.predict(X_test)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     263             This estimator
#     264         """
# --> 265         Xt, fit_params = self._fit(X, y, **fit_params)
#     266         if self._final_estimator is not None:
#     267             self._final_estimator.fit(Xt, y, **fit_params)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params)
#     228                 Xt, fitted_transformer = fit_transform_one_cached(
#     229                     cloned_transformer, Xt, y, None,
# --> 230                     **fit_params_steps[name])
#     231                 # Replace the transformer of the step with the fitted
#     232                 # transformer. This is necessary when loading the transformer
#
# /anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     327
#     328     def __call__(self, *args, **kwargs):
# --> 329         return self.func(*args, **kwargs)
#     330
#     331     def call_and_shelve(self, *args, **kwargs):
#
# /anaconda3/lib/python3.6/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, **fit_params)
#     612 def _fit_transform_one(transformer, X, y, weight, **fit_params):
#     613     if hasattr(transformer, 'fit_transform'):
# --> 614         res = transformer.fit_transform(X, y, **fit_params)
#     615     else:
#     616         res = transformer.fit(X, y, **fit_params).transform(X)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1010
#    1011         vocabulary, X = self._count_vocab(raw_documents,
# -> 1012                                           self.fixed_vocabulary_)
#    1013
#    1014         if self.binary:
#
# /anaconda3/lib/python3.6/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     920         for doc in raw_documents:
#     921             feature_counter = {}
# --> 922             for feature in analyze(doc):
#     923                 try:
#     924                     feature_idx = vocabulary[feature]
#
# /anaconda3/lib/python3.6/site-packages/sklearn/feature_extraction/text.py in <lambda>(doc)
#     306                                                tokenize)
#     307             return lambda doc: self._word_ngrams(
# --> 308                 tokenize(preprocess(self.decode(doc))), stop_words)
#     309
#     310         else:
#
# /anaconda3/lib/python3.6/site-packages/sklearn/feature_extraction/text.py in _word_ngrams(self, tokens, stop_words)
#     173                             min(max_n + 1, n_original_tokens + 1)):
#     174                 for i in xrange(n_original_tokens - n + 1):
# --> 175                     tokens_append(space_join(original_tokens[i: i + n]))
#     176
#     177         return tokens
#
# KeyboardInterrupt:
